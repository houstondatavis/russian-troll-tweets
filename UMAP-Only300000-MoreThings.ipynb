# %% [markdown]
# # Test B - Quick Loop at Russian Troll Dataset Using UMAP and some of the fields - only 300,000 of 3 million rows

# %% [markdown]
# ### GOING THROUGH THIS DEMO: https://umap-learn.readthedocs.io/en/latest/clustering.html#traditional-clustering but with this dataset of Russian Twitter Trolls

# %% [markdown]
#  We're using the features that can be easily converted into integer based datatypes from strings and either post_type or account_type as the label we're trying to optimize for

# %% [markdown]
# We expect to see a lot of overlap with these features but not complete as we expect the catagories of accounts to post on twitter over a a range of dates, times, regions, languages, retweet levels, etc.

# %% [markdown]
# What we see is there is a little more separation than maybe I expected but still a lot of overlap

# %% [markdown]
# ## I suspect if we used SpaCY (a library for natural language processing) to extract terms and keywords from the content field of each tweet, we could then back into the account_types field as that's probably similar to how they go it in the first place.
# Maybe this might be starting point: https://www.kaggle.com/joeytaj/nlp-parsing-example-using-spacy

# %% [markdown]
# We do see a little interesting behavior in that commercial and some other types of tweets seem to have more separation? Something to investigate later, maybe?

# %% [markdown]
# Justin Gosses - 2018-08 , need to go back through and redo as I spotted some errors

# %%
import numpy as np
from sklearn.datasets import load_iris, load_digits
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline
import glob as glob
# Out:
# /Users/justingosses/anaconda/envs/MannvilleDask2/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
import hdbscan
import sklearn.cluster as cluster
from sklearn.metrics import adjusted_rand_score, adjusted_mutual_info_score
# Out:
# /Users/justingosses/anaconda/envs/MannvilleDask2/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
from sklearn.decomposition import PCA

# %%
sns.set(style='white', context='notebook', rc={'figure.figsize':(14,10)})

# %%
import umap

# %%
reducer = umap.UMAP()

# %%
knn_dir = "../WellsKNN/"
load_dir = "../loadLAS"
features_dir = "../createFeatures/"

# %%
path =r'.' # use your path
allFiles = glob.glob(path + "/*.csv")
frame = pd.DataFrame()
list_ = []
for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
frame = pd.concat(list_)

# %%
frame_1 = frame.copy()

# %%
frame_1.head()
# Out:
#    external_author_id      author  \
# 0        1.674084e+09  GAB1ALDANA
# 1        1.674084e+09  GAB1ALDANA
# 2        1.674084e+09  GAB1ALDANA
# 3        1.674084e+09  GAB1ALDANA
# 4        1.674084e+09  GAB1ALDANA
#
#                                              content         region  \
# 0  People are too toxic. I think I have people po...  United States
# 1  #NowPlaying Don't Shoot (I'm a Man) by @DEVO -...  United States
# 2  the 'I'm the most boring person in the world' ...  United States
# 3  #MyAchillesHeel slippery floors https://t.co/R...  United States
# 4  #MyAchillesHeel Boring narcissists.....nothing...  United States
#
#     language     publish_date   harvested_date  following  followers  updates  \
# 0    English  7/30/2016 20:15  7/30/2016 20:15       3395       2014     2150
# 1    English  7/30/2016 20:15  7/30/2016 20:15       3395       2014     2146
# 2    English  7/30/2016 20:16  7/30/2016 20:16       3395       2013     2159
# 3  Norwegian  7/30/2016 20:16  7/30/2016 20:16       3395       2013     2160
# 4    English  7/30/2016 20:16  7/30/2016 20:16       3395       2013     2158
#
#   post_type account_type  new_june_2018  retweet account_category
# 0   RETWEET    Hashtager              0        1     HashtagGamer
# 1   RETWEET    Hashtager              0        1     HashtagGamer
# 2   RETWEET    Hashtager              0        1     HashtagGamer
# 3   RETWEET    Hashtager              0        1     HashtagGamer
# 4   RETWEET    Hashtager              0        1     HashtagGamer

# %%
all_col = list(frame_1.columns)

# %%
all_col
# Out:
# ['external_author_id',
#  'author',
#  'content',
#  'region',
#  'language',
#  'publish_date',
#  'harvested_date',
#  'following',
# 24        2089   RETWEET    Hashtager              0        1     HashtagGamer
# 25        2088   RETWEET    Hashtager              0        1     HashtagGamer
# 26         604       NaN    Hashtager              0        0     HashtagGamer
# 27         605       NaN    Hashtager              0        0     HashtagGamer
# 28         607       NaN    Hashtager              0        0     HashtagGamer
# 29        1936       NaN    Hashtager              0        0     HashtagGamer
# ...        ...       ...          ...            ...      ...              ...
# 37525      400       NaN      Russian              0        0       NonEnglish
# 37526      428       NaN      Russian              0        0       NonEnglish
# 37527      429       NaN      Russian              0        0       NonEnglish
# 37528      430       NaN      Russian              0        0       NonEnglish
# 37529      431       NaN      Russian              0        0       NonEnglish
# 37530      432       NaN      Russian              0        0       NonEnglish
# 37531      433       NaN      Russian              0        0       NonEnglish
# 37532      434       NaN      Russian              0        0       NonEnglish
# 37533      435       NaN      Russian              0        0       NonEnglish
# 37534      436       NaN      Russian              0        0       NonEnglish
# 37535      437       NaN      Russian              0        0       NonEnglish
# 37536      403       NaN      Russian              0        0       NonEnglish
# 37537      438       NaN      Russian              0        0       NonEnglish
# 37538      439       NaN      Russian              0        0       NonEnglish
# 37539      404       NaN      Russian              0        0       NonEnglish
# 37540      405       NaN      Russian              0        0       NonEnglish
# 37541      406       NaN      Russian              0        0       NonEnglish
# 37542      407       NaN      Russian              0        0       NonEnglish
# 37543      410       NaN      Russian              0        0       NonEnglish
# 37544      408       NaN      Russian              0        0       NonEnglish
# 37545      411       NaN      Russian              0        0       NonEnglish
# 37546      409       NaN      Russian              0        0       NonEnglish
# 37547      414       NaN      Russian              0        0       NonEnglish
# 37548      415       NaN      Russian              0        0       NonEnglish
# 37549      413       NaN      Russian              0        0       NonEnglish
# 37550      412       NaN      Russian              0        0       NonEnglish
# 37551      416       NaN      Russian              0        0       NonEnglish
# 37552      418       NaN      Russian              0        0       NonEnglish
# 37553      419       NaN      Russian              0        0       NonEnglish
# 37554      417       NaN      Russian              0        0       NonEnglish
#
# [2973371 rows x 15 columns]

# %%
#frame_1['account_category_codes'] = frame_1.account_category.cat.codes

# %%
frame_1.account_category = pd.Categorical(frame_1.account_category)
frame_1['account_category_codes'] = frame_1.account_category.cat.codes
frame_1['post_type_codes'] = pd.Categorical(frame_1.post_type)
frame_1['post_type_codes'] = frame_1.post_type_codes.cat.codes
frame_1['language_codes'] = pd.Categorical(frame_1.language)
frame_1['language_codes'] = frame_1.language_codes.cat.codes
frame_1['author_codes'] = pd.Categorical(frame_1.author)
frame_1['author_codes'] = frame_1.author_codes.cat.codes
frame_1['region_codes'] = pd.Categorical(frame_1.region)
frame_1['region_codes'] = frame_1.region_codes.cat.codes
frame_1['post_type_codes'] = pd.Categorical(frame_1.post_type)
frame_1['post_type_codes'] = frame_1.post_type_codes.cat.codes
frame_1['account_type_codes'] = pd.Categorical(frame_1.account_type)
frame_1['account_type_codes'] = frame_1.account_type_codes.cat.codes
frame_1['external_author_id_codes'] = pd.Categorical(frame_1.external_author_id)
frame_1['external_author_id_codes'] = frame_1.external_author_id_codes.cat.codes

# %%
frame_1.columns
# Out:
# Index(['external_author_id', 'author', 'content', 'region', 'language',
#        'publish_date', 'harvested_date', 'following', 'followers', 'updates',
#        'post_type', 'account_type', 'new_june_2018', 'retweet',
#        'account_category', 'account_category_codes', 'post_type_codes',
#        'language_codes', 'author_codes', 'region_codes', 'account_type_codes',
#        'external_author_id_codes'],
#       dtype='object')

# %%
frame_2 = frame_1[['following', 'followers', 'updates','retweet', 'account_category_codes', 'post_type_codes',
       'language_codes', 'author_codes', 'region_codes', 'account_type_codes',
       'external_author_id_codes']]

# %%
frame_3 = frame_2[0:200000]

# %%
frame_3_col = frame_3.columns
frame_3_col
# Out:
# Index(['following', 'followers', 'updates', 'retweet',
#        'account_category_codes', 'post_type_codes', 'language_codes',
#        'author_codes', 'region_codes', 'account_type_codes',
#        'external_author_id_codes'],
#       dtype='object')

# %%
frame_3 = frame_3.fillna(0)

# %%
account_category_val = frame_1.account_category.unique()
account_category_codes_val = frame_1.account_category_codes.unique()
list_codes = []
count = 0
for i in account_category_val:
    dict_codes = {}
    i = count
    dict_codes[account_category_val[i]] = account_category_codes_val[i]
#     dict_codes['account_category_val'] = account_category_val[i]
#     dict_codes['account_category_codes_val'] = account_category_codes_val[i]
    count += 1
    list_codes.append(dict_codes) 
print(list_codes)
# print(account_category_val)
# print(account_category_codes_val)
# Out:
# [{'HashtagGamer': 2}, {'Fearmonger': 1}, {'NonEnglish': 5}, {'LeftTroll': 3}, {'RightTroll': 6}, {'Unknown': 7}, {'NewsFeed': 4}, {'Commercial': 0}]

# %%
reducer = umap.UMAP()

# %%
standard_embedding = umap.UMAP(random_state=42).fit_transform(frame_3)
plt.scatter(standard_embedding[:, 0], standard_embedding[:, 1], c=frame_3.account_category_codes, s=0.1, cmap='Spectral')
plt.colorbar(boundaries=np.arange(11)-0.5).set_ticks(np.arange(10));
# Out:
# /Users/justingosses/anaconda/envs/MannvilleDask2/lib/python3.6/site-packages/umap/spectral.py:229: UserWarning: Embedding 1451 connected components using meta-embedding (experimental)
#   n_components
# /Users/justingosses/anaconda/envs/MannvilleDask2/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:234: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"

# %%
kmeans_labels = cluster.KMeans(n_clusters=10).fit_predict(frame_3)

# %%
plt.scatter(standard_embedding[:, 0], standard_embedding[:, 1], c=kmeans_labels, s=0.1, cmap='Spectral');
plt.colorbar(boundaries=np.arange(11)-0.5).set_ticks(np.arange(7))

# %%
(
    adjusted_rand_score(frame_3.account_category_codes, kmeans_labels),
    adjusted_mutual_info_score(frame_3.account_category_codes, kmeans_labels)
)
# Out:
# (0.06519893846683125, 0.17642921598930378)

# %% [markdown]
# -------------------

# %%
lowd_frame_3 = PCA(n_components=9).fit_transform(frame_3)
hdbscan_labels = hdbscan.HDBSCAN(min_samples=10, min_cluster_size=500).fit_predict(lowd_frame_3)

# %%
clustered = (hdbscan_labels >= 0)
plt.scatter(standard_embedding[~clustered, 0],
            standard_embedding[~clustered, 1],
            c=(0.5, 0.5, 0.5),
            s=0.1,
            alpha=0.5)
plt.scatter(standard_embedding[clustered, 0],
            standard_embedding[clustered, 1],
            c=hdbscan_labels[clustered],
            s=0.1,
            cmap='Spectral');

# %%
(
    adjusted_rand_score(frame_3.account_category_codes, hdbscan_labels),
    adjusted_mutual_info_score(frame_3.account_category_codes, hdbscan_labels)
)
# Out:
# (0.04885010649557174, 0.27027273662866097)

# %%
clustered = (hdbscan_labels >= 0)
(
    adjusted_rand_score(frame_3.account_category_codes[clustered], hdbscan_labels[clustered]),
    adjusted_mutual_info_score(frame_3.account_category_codes[clustered], hdbscan_labels[clustered])
)
# Out:
# (0.07798987345764319, 0.30078611704081987)

# %%
np.sum(clustered) / frame_3.shape[0]
# Out:
# 0.829825

# %%
embedding  = reducer.fit_transform(frame_3)
embedding.shape
# Out:
# /Users/justingosses/anaconda/envs/MannvilleDask2/lib/python3.6/site-packages/umap/spectral.py:229: UserWarning: Embedding 1442 connected components using meta-embedding (experimental)
#   n_components
# /Users/justingosses/anaconda/envs/MannvilleDask2/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:234: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# (200000, 2)

# %%
print(list_codes)
# Out:
# [{'HashtagGamer': 2}, {'Fearmonger': 1}, {'NonEnglish': 5}, {'LeftTroll': 3}, {'RightTroll': 6}, {'Unknown': 7}, {'NewsFeed': 4}, {'Commercial': 0}]

# %%
plt.scatter(embedding[:, 0], embedding[:, 1], c=frame_3.account_category_codes, cmap='Spectral', s=5)
plt.gca().set_aspect('equal', 'datalim')
plt.colorbar(boundaries=np.arange(11)-0.5).set_ticks(np.arange(10))
plt.title('UMAP projection of the dataset', fontsize=24);

# %%
clusterable_embedding = umap.UMAP(
    n_neighbors=30,
    min_dist=0.0,
    n_components=2,
    random_state=42,
).fit_transform(frame_3)
# Out:
# /Users/justingosses/anaconda/envs/MannvilleDask2/lib/python3.6/site-packages/umap/spectral.py:229: UserWarning: Embedding 965 connected components using meta-embedding (experimental)
#   n_components
# /Users/justingosses/anaconda/envs/MannvilleDask2/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:234: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"

# %%
plt.scatter(clusterable_embedding[:, 0], clusterable_embedding[:, 1],
            c=frame_3.account_category_codes, s=0.1, cmap='Spectral');

# %%
labels = hdbscan.HDBSCAN(
    min_samples=10,
    min_cluster_size=500,
).fit_predict(clusterable_embedding)

# %%
clustered = (labels >= 0)
plt.scatter(standard_embedding[~clustered, 0],
            standard_embedding[~clustered, 1],
            c=(0.5, 0.5, 0.5),
            s=0.1,
            alpha=0.5)
plt.scatter(standard_embedding[clustered, 0],
            standard_embedding[clustered, 1],
            c=labels[clustered],
            s=0.1,
            cmap='Spectral');

# %%
adjusted_rand_score(frame_3.account_category_codes, labels), adjusted_mutual_info_score(frame_3.account_category_codes, labels)
# Out:
# (0.015640521213690205, 0.14180606402539084)

# %%
clustered = (labels >= 0)
(
    adjusted_rand_score(frame_3.account_category_codes[clustered], labels[clustered]),
    adjusted_mutual_info_score(frame_3.account_category_codes[clustered], labels[clustered])
)
# Out:
# (0.03863209581393145, 0.15205137080793257)

# %%
np.sum(clustered) / frame_3.account_category_codes.shape[0]
# Out:
# 0.774995

# %%
frame_1[0:800]
# Out:
#      external_author_id      author  \
# 0          1.674084e+09  GAB1ALDANA
# 1          1.674084e+09  GAB1ALDANA
# 2          1.674084e+09  GAB1ALDANA
# 3          1.674084e+09  GAB1ALDANA
# 4          1.674084e+09  GAB1ALDANA
# 5          1.674084e+09  GAB1ALDANA
# 6          1.674084e+09  GAB1ALDANA
# 7          1.674084e+09  GAB1ALDANA
# 8          1.674084e+09  GAB1ALDANA
# 9          1.674084e+09  GAB1ALDANA
# 10         1.674084e+09  GAB1ALDANA
# 11         1.674084e+09  GAB1ALDANA
# 12         1.674084e+09  GAB1ALDANA
# 13         1.674084e+09  GAB1ALDANA
# 14         1.674084e+09  GAB1ALDANA
# 15         1.674084e+09  GAB1ALDANA
# 16         1.674084e+09  GAB1ALDANA
# 20                           Toking aces  #SpliffFilms  United States
# 21   May your faith be unshakeable and your will, u...  United States
# 22   A town called alice springs #takeasongaroundth...  United States
# 23   Explaining time to humanoid Earth-dwellers... ...  United States
# 24            Argh! Beast dog. https://t.co/No7EAqtLZG  United States
# 25                  Rolling For Columbine #SpliffFilms  United States
# 26                 Outta my way! #UnitedStatesIn3Words  United States
# 27        Crazy. Beautiful. Love #UnitedStatesIn3Words  United States
# 28          #UnitedStatesIn3Words unfair, bossy, broke  United States
# 29   RT @midnight: Pack your boxes, tonight we're p...  United States
# ..                                                 ...            ...
# 770  #MyBestFriendIsntAllowed to enter the room if ...  United States
# 771  contrary to widespread belief if jules kroll's...  United States
# 772  6,8 gallons of beer are needed to get calcium ...  United States
# 773  #MyBestFriendIsntAllowed to play minecraft any...  United States
# 774  #MyBestFriendIsntAllowed to exist. They tell m...  United States
# 775  #MyBestFriendIsntAllowed to be their own perso...  United States
# 776  #MyBestFriendIsntAllowed to touch my Eggo http...  United States
# 777  #IHaveARightToKnow how big the bath was https:...  United States
# 778  Noesy ppl be like #IHaveARightToKnow. But it's...  United States
# 779  "Theres no reason to look back when you have s...  United States
# 780  #IHaveARightToKnow why radio stations always p...  United States
# 781  #IHaveARightToKnow how experienced you are bef...  United States
# 782  #IHaveARightToKnow why Im not recognized as Ul...  United States
# 783  #IHaveARightToKnow why you would vote for @Hil...  United States
# 784  #IHaveARightToKnow what answer is blowing in t...  United States
# 785  #IHaveARightToKnow who just used that bathroom...  United States
# 786  #IHaveARightToKnow why that drunken rodeo clow...  United States
# 787  #IHaveARightToKnow if she said I'm cute... htt...  United States
# 788  #IHaveARightToKnow if Hillary Clinton, is actu...  United States
# 789  something interesting is happening in the ethe...  United States
# 790  #ihavearighttoknow why 60% of the TV shows I e...  United States
# 791  #IHaveARightToKnow what my elected officials a...  United States
# 792  #IHaveARightToKnow why @HillaryClinton  delete...  United States
# 793  #IHaveARightToKnow Why we drive on parkways an...  United States
# 794  #IHaveARightToKnow who keeps making up these n...  United States
# 795             #IHaveARightToKnow why it's not butter  United States
# 796  #IHaveARightToKnow why you haven't VOTED FOR M...  United States
# 797  #IHaveARightToKnow HOW THEY GET THE CAFFEINE O...  United States
# 798  How to survive a Walmart trip and not to go bl...  United States
# 799        #IHaveARightToKnow what you put in my drink  United States
#
#       language     publish_date   harvested_date  following  followers  \
# 0      English  7/30/2016 20:15  7/30/2016 20:15       3395       2014
# 1      English  7/30/2016 20:15  7/30/2016 20:15       3395       2014
# 2      English  7/30/2016 20:16  7/30/2016 20:16       3395       2013
# 3    Norwegian  7/30/2016 20:16  7/30/2016 20:16       3395       2013
# 4      English  7/30/2016 20:16  7/30/2016 20:16       3395       2013
# 5      English  7/30/2016 20:16  7/30/2016 20:16       3395       2014
# 6      English  7/30/2016 20:16  7/30/2016 20:16       3395       2013
# 7      English  7/30/2016 20:16  7/30/2016 20:16       3395       2013
# 8      English  7/30/2016 20:17  7/30/2016 20:17       3395       2013
# 9      English  7/30/2016 20:17  7/30/2016 20:17       3395       2013
# 10     English  7/30/2016 20:17  7/30/2016 20:18       3395       2013
# 11     English  7/30/2016 20:17  7/30/2016 20:17       3395       2013
# 12     English  7/30/2016 20:17  7/30/2016 20:17       3395       2013
#
# 1       2146            ...                        0       1
# 2       2159            ...                        0       1
# 3       2160            ...                        0       1
# 4       2158            ...                        0       1
# 5       2154            ...                        0       1
# 6       2156            ...                        0       1
# 7       2157            ...                        0       1
# 8       2161            ...                        0       1
# 9       2167            ...                        0       1
# 10      2169            ...                        0       1
# 11      2163            ...                        0       1
# 12      2162            ...                        0       1
# 13      2168            ...                        0       1
# 14      2074            ...                        0       0
# 15      2075            ...                        0       0
# 16      2078            ...                        0       1
# 17      2079            ...                        0       1
# 18      2077            ...                        0       1
# 19      2076            ...                        0       1
# 20      2080            ...                        0       1
# 21      2083            ...                        0       1
# 22      2086            ...                        0       1
# 23      2090            ...                        0       1
# 24      2089            ...                        0       1
# 25      2088            ...                        0       1
# 26       604            ...                        0       0
# 27       605            ...                        0       0
# 28       607            ...                        0       0
# 29      1936            ...                        0       0
# ..       ...            ...                      ...     ...
# 770     3268            ...                        0       1
# 771     3265            ...                        0       1
# 772     3270            ...                        0       1
# 773     3266            ...                        0       1
# 774     3267            ...                        0       1
# 775     3271            ...                        0       1
# 776     3272            ...                        0       1
# 777     3277            ...                        0       1
# 778     3279            ...                        0       1
# 779     3274            ...                        0       1
# 780     3287            ...                        0       1
# 781     3283            ...                        0       1
# 782     3280            ...                        0       1
# 783     3286            ...                        0       1
# 784     3284            ...                        0       1
# 785     3290            ...                        0       1
# 786     3295            ...                        0       1
# 787     3291            ...                        0       1
# 788     3294            ...                        0       1
# 789     3289            ...                        0       1
# 790     3297            ...                        0       1
# 791     3296            ...                        0       1
# 792     3298            ...                        0       1
# 793     3299            ...                        0       0
# 794     3304            ...                        0       1
# 795     3303            ...                        0       1
# 796     3300            ...                        0       1
# 797     3301            ...                        0       1
# 798     3305            ...                        0       1
# 799     3313            ...                        0       1
#
#      account_category  account_category_codes post_type_codes  language_codes  \
# 0        HashtagGamer                       2               1               9
# 1        HashtagGamer                       2               1               9
# 2        HashtagGamer                       2               1               9
# 3        HashtagGamer                       2               1              33
# 4        HashtagGamer                       2               1               9
# 5        HashtagGamer                       2               1               9
# 6        HashtagGamer                       2               1               9
# 7        HashtagGamer                       2               1               9
# 8        HashtagGamer                       2               1               9
# 9        HashtagGamer                       2               1               9
# 10       HashtagGamer                       2               1               9
# 11       HashtagGamer                       2               1               9
# 12       HashtagGamer                       2               1               9
# 13       HashtagGamer                       2               1               9
# 14       HashtagGamer                       2              -1               9
# 15       HashtagGamer                       2              -1               9
# 16       HashtagGamer                       2               1               9
# 17       HashtagGamer                       2               1               9
# 18       HashtagGamer                       2               1               9
# 19       HashtagGamer                       2               1               9
# 20       HashtagGamer                       2               1               9
# 21       HashtagGamer                       2               1               9
# 22       HashtagGamer                       2               1               9
# 23       HashtagGamer                       2               1               9
# 24       HashtagGamer                       2               1               9
# 25       HashtagGamer                       2               1               9
# 26       HashtagGamer                       2              -1               9
# 27       HashtagGamer                       2              -1               9
# 28       HashtagGamer                       2              -1               9
# 29       HashtagGamer                       2              -1               9
# ..                ...                     ...             ...             ...
# 770      HashtagGamer                       2               1               9
# 771      HashtagGamer                       2               1               9
# 772      HashtagGamer                       2               1               9
# 773      HashtagGamer                       2               1               9
# 774      HashtagGamer                       2               1               9
# 775      HashtagGamer                       2               1               9
# 776      HashtagGamer                       2               1               9
# 777      HashtagGamer                       2               1               9
# 778      HashtagGamer                       2               1               9
# 779      HashtagGamer                       2               1               9
# 780      HashtagGamer                       2               1               9
# 781      HashtagGamer                       2               1               9
# 782      HashtagGamer                       2               1               9
# 783      HashtagGamer                       2               1               9
# 784      HashtagGamer                       2               1               9
# 785      HashtagGamer                       2               1               9
# 786      HashtagGamer                       2               1               9
# 787      HashtagGamer                       2               1               9
# 788      HashtagGamer                       2               1               9
# 789      HashtagGamer                       2               1               9
# 790      HashtagGamer                       2               1               9
# 791      HashtagGamer                       2               1               9
# 792      HashtagGamer                       2               1               9
# 793      HashtagGamer                       2              -1               9
# 794      HashtagGamer                       2               1               9
# 795      HashtagGamer                       2               1               9
# 796      HashtagGamer                       2               1               9
# 797      HashtagGamer                       2               1               9
# 798      HashtagGamer                       2               1               9
# 799      HashtagGamer                       2               1               9
#
#      author_codes  region_codes  account_type_codes  external_author_id_codes
# 0             946            34                   6                       432
# 1             946            34                   6                       432
# 2             946            34                   6                       432
# 3             946            34                   6                       432
# 4             946            34                   6                       432
# 5             946            34                   6                       432
# 6             946            34                   6                       432
# 7             946            34                   6                       432
# 8             946            34                   6                       432
# 9             946            34                   6                       432
# 10            946            34                   6                       432
# 11            946            34                   6                       432
# 12            946            34                   6                       432
# 13            946            34                   6                       432
# 14            946            34                   6                       432
# 15            946            34                   6                       432
# 16            946            34                   6                       432
# 17            946            34                   6                       432
# 18            946            34                   6                       432
# 19            946            34                   6                       432
# 20            946            34                   6                       432
# 21            946            34                   6                       432
# 22            946            34                   6                       432
# 23            946            34                   6                       432
# 24            946            34                   6                       432
# 25            946            34                   6                       432
# 26            946            34                   6                       432
# 27            946            34                   6                       432
# 28            946            34                   6                       432
# 29            946            34                   6                       432
# ..            ...           ...                 ...                       ...
# 770           946            34                   6                       432
# 771           946            34                   6                       432
# 772           946            34                   6                       432
# 773           946            34                   6                       432
# 774           946            34                   6                       432
# 775           946            34                   6                       432
# 776           946            34                   6                       432
# 777           946            34                   6                       432
# 778           946            34                   6                       432
# 779           946            34                   6                       432
# 780           946            34                   6                       432
# 781           946            34                   6                       432
# 782           946            34                   6                       432
# 783           946            34                   6                       432
# 784           946            34                   6                       432
# 785           946            34                   6                       432
# 786           946            34                   6                       432
# 787           946            34                   6                       432
# 788           946            34                   6                       432
# 789           946            34                   6                       432
# 790           946            34                   6                       432
# 791           946            34                   6                       432
# 792           946            34                   6                       432
# 793           946            34                   6                       432
# 794           946            34                   6                       432
# 795           946            34                   6                       432
# 796           946            34                   6                       432
# 797           946            34                   6                       432
# 798           946            34                   6                       432
# 799           946            34                   6                       432
#
# [800 rows x 22 columns]

# %%
#frame_3[0:800]

# %%
plt.scatter(embedding[:, 0], embedding[:, 1], c=frame_3.account_type_codes, cmap='Spectral', s=5)
plt.gca().set_aspect('equal', 'datalim')
plt.colorbar(boundaries=np.arange(11)-0.5).set_ticks(np.arange(10))
plt.savefig('books_read.png', dpi=100)
plt.title('UMAP projection of the dataset', fontsize=24);
